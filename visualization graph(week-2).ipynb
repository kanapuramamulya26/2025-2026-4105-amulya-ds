# %% [markdown]
# <a href="https://colab.research.google.com/github/kanapuramamulya26/2025-2026-4105-amulya-ds/blob/main/visualization%20graph(week-2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Data Visualization using Matplotlib
import matplotlib.pyplot as plt
import numpy as np

# Sample data
x = np.arange(1, 6)  # X-axis: 1 to 5
y = np.array([10, 15, 7, 12, 9])  # Y-axis values
categories = ['A', 'B', 'C', 'D', 'E']

# -----------------------------
# a) Line Graph
plt.figure(figsize=(6,4))
plt.plot(x, y, marker='o', color='blue', linestyle='-')
plt.title("Line Graph")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid(True)
plt.show()

# %%
# b) Bar Graph
plt.figure(figsize=(6,4))
plt.bar(categories, y, color='orange', edgecolor='black')
plt.title("Bar Graph")
plt.xlabel("Categories")
plt.ylabel("Values")
plt.show()

# %%
# c) Scatter Plot
plt.figure(figsize=(6,4))
plt.scatter(x, y, color='green', s=100)
plt.title("Scatter Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
#d) Histogram
data = np.random.randint(1, 20, 50)  # 50 random integers between 1 and 20
plt.figure(figsize=(6,4))
plt.hist(data, bins=8, color='purple', edgecolor='black')
plt.title("Histogram")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.show()

# %%
# e) Pie Chart
sizes = [25, 15, 30, 10, 20]  # Percentage values
plt.figure(figsize=(6,6))
plt.pie(sizes, labels=categories, autopct='%1.1f%%', startangle=90, colors=['red','blue','green','orange','purple'])
plt.title("Pie Chart")
plt.show()

# %%
# Sample data
arr = [64, 25, 12, 22, 11]

print("Original Array:", arr)
#Insertion Sort
def insertion_sort(lst):
    for i in range(1, len(lst)):
        key = lst[i]
        j = i - 1
        while j >= 0 and key < lst[j]:
            lst[j+1] = lst[j]
            j -= 1
        lst[j+1] = key
    return lst

insertion_sorted = insertion_sort(arr.copy())
print("Insertion Sorted Array:", insertion_sorted)
# Out:
# Original Array: [64, 25, 12, 22, 11]
# Insertion Sorted Array: [11, 12, 22, 25, 64]
